# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime

# %%
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, HistGradientBoostingClassifier, StackingClassifier, ExtraTreesClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
import optuna
import joblib

# %%
from src.load_data import get_train_data, get_test_data
from src.preprocessing.soil_types_encoding import add_soil_type_breakdown, remove_soil_type_columns
from src.preprocessing.feature_engineering import get_final_features
from src.evaluation import evaluate_model_performance, get_val_predictions
from src.create_submission_file import create_submission_file

# %% [markdown]
# # Data prep

# %%
X_train, y_train = get_train_data()
X_test = get_test_data()

# %%
# RESAMPLING TRIAL

# # Combine X_train and y_train for convenience
# train_df = X_train.copy()
# train_df['target'] = y_train

# # Map each row to its wilderness area category (0-3)
# wilderness_features = [col for col in X_test.columns if col.startswith("Wilderness_Area")]
# train_df['wilderness_area_cat'] = train_df[wilderness_features].idxmax(axis=1)
# test_df = X_test.copy()
# test_df['wilderness_area_cat'] = test_df[wilderness_features].idxmax(axis=1)

# # Compute test distribution of wilderness areas
# test_dist = test_df['wilderness_area_cat'].value_counts(normalize=True)

# resampled_list = []

# # Sample rows for each wilderness area according to test proportions
# n_total = len(train_df)
# for w_area, prop in test_dist.items():
#     n_samples = int(round(prop * n_total))
#     available_rows = train_df[train_df['wilderness_area_cat'] == w_area]

#     # sample with replacement if needed
#     sampled_rows = available_rows.sample(n=n_samples, replace=True, random_state=42)
#     resampled_list.append(sampled_rows)

# # Combine all sampled rows
# resampled_train = pd.concat(resampled_list).sample(frac=1, random_state=42).reset_index(drop=True)

# resampled_train = resampled_train.drop(columns=['wilderness_area_cat'])
# X_train_resampled = resampled_train.drop(columns=['target'])
# y_train_resampled = resampled_train['target']

# # Optional: check distributions
# print("Wilderness area distribution after resampling:")
# print(resampled_train[wilderness_features].mean())
# print("\nClass distribution after resampling (targets may shift):")
# print(resampled_train['target'].value_counts(normalize=True))

# X_train_pcd = X_train_resampled.copy()
# y_train = y_train_resampled.copy()

# %%
X_train_pcd = X_train.copy()
X_train_pcd = get_final_features(X_train_pcd)
X_train_pcd = add_soil_type_breakdown(X_train_pcd)
X_train_pcd = remove_soil_type_columns(X_train_pcd)

# %%
X_test_pcd = X_test.copy()
X_test_pcd = get_final_features(X_test_pcd)
X_test_pcd = add_soil_type_breakdown(X_test_pcd)
X_test_pcd = remove_soil_type_columns(X_test_pcd)
X_test_pcd = X_test_pcd[X_train_pcd.columns]

# %%
X_train_pcd

# %%
X_test_pcd

# %% [markdown]
# # Modelling

# %% [markdown]
# ## Logistic regression for first baseline

# %%
# logreg_model = make_pipeline(
#     StandardScaler(),
#     LogisticRegression(
#         max_iter=1000,
#     ),
# )
# evaluate_model_performance(logreg_model, X_train_pcd, y_train)

# %% [markdown]
# ## Random forest

# %%
cand_depths = list(range(10,30))
train_scores = []
validate_scores = []

for d in cand_depths:
    print(f"{d=}")
    rf_model = RandomForestClassifier(
        max_depth=d, random_state=1
    )
    train_score, validate_score = evaluate_model_performance(
        rf_model, X_train_pcd, y_train
    )
    train_scores.append(train_score)
    validate_scores.append(validate_score)
    print("--")
    print()

# %%
plt.figure(figsize=(7, 4))

plt.plot(cand_depths, train_scores, marker="o", label="Train")
plt.plot(cand_depths, validate_scores, marker="s", label="Validate")

plt.title("Evaluating Random Forest Classifier using 5-fold Stratified CV")
plt.ylabel("Mean accuracy across folds")
plt.xlabel("Max Depth")
plt.legend()

plt.xticks(cand_depths[::5])
plt.grid(alpha=0.2)
plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(10, 6))

# plt.plot(cand_depths, train_scores, marker="o", label="Train")
plt.plot(cand_depths, validate_scores, marker="s", label="Validate")

plt.title("Tuning Max Depth for Random Forest Classifier using 5-fold Stratified Group CV")
plt.ylabel("Mean balanced accuracy across folds")
plt.xlabel("Max Depth")
plt.legend()

plt.xticks(cand_depths)
plt.grid(alpha=0.2)

plt.show()

# %%
cand_depths[np.argmax(validate_scores)]

# %%
rf_model = RandomForestClassifier(max_depth=25, random_state=1)
evaluate_model_performance(rf_model, X_train_pcd, y_train)

# %%
# create_submission_file(
#     rf_model,
#     X_train_pcd,
#     y_train,
#     X_test_pcd,
#     save_name="rf_model",
# )

# %%
# rf_model.fit(X_train_pcd, y_train)
# joblib.dump(rf_model, "models/rf_model.pkl")

# %% [markdown]
# ## HGBClassifier with hyperparameter tuning using Optuna

# %%
# def objective(trial):
#     params = {
#         "max_iter": 1000,
#         "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.2, log=True),
#         "max_depth": trial.suggest_int("max_depth", 1, 20),
#         "l2_regularization": trial.suggest_float("l2_regularization", 0.0, 10.0),
#         "random_state": 1,
#         "class_weight": "balanced",
#     }

#     model = HistGradientBoostingClassifier(**params)
#     _, validate_score = evaluate_model_performance(
#         model, X_train_pcd, y_train
#     )

#     return validate_score


# study = optuna.create_study(direction="maximize")
# study.optimize(objective, n_trials=10)

# print("Best params:", study.best_params)
# print("Best score:", study.best_value)

# %%
# hgb_model = HistGradientBoostingClassifier(
#     max_iter=1000,
#     random_state=1,
#     **study.best_params
# )
# create_submission_file(
#     hgb_model,
#     X_train_pcd,
#     y_train,
#     X_test_pcd,
#     save_name="hgb_model_optuna_tuning",
# )

# %%
# hgb_model.fit(X_train_pcd, y_train)
# joblib.dump(hgb_model, "models/hgb_model.pkl")

# %% [markdown]
# ## XGBoost

# %%
# le = LabelEncoder()
# y_encoded = le.fit_transform(y_train)

# print("Encoded labels:", np.unique(y_encoded))
# print("Number of classes:", len(le.classes_))

# xgb_model = XGBClassifier()
# evaluate_model_performance(xgb_model, X_train_pcd, y_encoded)

# %%
# xgb_model.fit(X_train_pcd, y_encoded)

# timestamp = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
# pd.DataFrame({"Id": X_test_pcd.index, "Cover_Type": xgb_model.predict(X_test_pcd) + 1}).to_csv(
#     f"output/xgb_{timestamp}.csv", index=False
# )

# %% [markdown]
# ## LGBM

# %%
# lgbm_model = LGBMClassifier()
# evaluate_model_performance(lgbm_model, X_train_pcd, y_train)

# # timestamp = datetime.datetime.now().stlgbmtime("%Y%m%d-%H%M%S")
# # pd.DataFrame({
# #     "Id": X_test.index,
# #     "Cover_Type": lgbm_model.predict(X_test)
# # }).to_csv(f"output/lgbm_{timestamp}.csv", index=False)

# %%
# create_submission_file(lgbm_model, X_train_pcd, y_train, X_test_pcd, save_name="lgbm_model_soiltype_breakdown")

# %% [markdown]
# ## Stacking

# %%
# # Base models
# base_estimators = [
#     (
#         "cat",
#         CatBoostClassifier(
#             loss_function="MultiClass",
#             verbose=0,
#         ),
#     ),
#     (
#         "lgbm",
#         LGBMClassifier(
#             n_estimators=500,
#             max_depth=-1,
#         ),
#     ),
#     (
#         "xgb",
#         XGBClassifier(
#             n_estimators=500,
#             learning_rate=0.05,
#         ),
#     ),
#     (
#         "hgb",
#         HistGradientBoostingClassifier(
#             max_iter=1000,
#             random_state=1,
#             **study.best_params
#         ),
#     ),
#     ("rf", RandomForestClassifier(max_depth=18, n_estimators=500)),
# ]

# meta_model = LogisticRegression()

# stack = StackingClassifier(
#     estimators=base_estimators,
#     final_estimator=meta_model,
#     cv=StratifiedKFold(n_splits=5),
#     stack_method="predict_proba",
#     n_jobs=-1,
# )

# %%
# # Base models
# base_estimators = [
#     (
#         "cat",
#         CatBoostClassifier(
#             loss_function="MultiClass",
#             verbose=0,
#         ),
#     ),
#     (
#         "lgbm",
#         LGBMClassifier(
#             n_estimators=500,
#             max_depth=-1,
#         ),
#     ),
#     (
#         "xgb",
#         XGBClassifier(
#             n_estimators=500,
#             learning_rate=0.05,
#         ),
#     ),
#     (
#         "hgb",
#         HistGradientBoostingClassifier(
#             max_iter=1000,
#             random_state=1,
#             **study.best_params
#         ),
#     ),
#     ("rf", RandomForestClassifier(max_depth=18, n_estimators=500)),
# ]

# meta_model = RandomForestClassifier()

# stack = StackingClassifier(
#     estimators=base_estimators,
#     final_estimator=meta_model,
#     cv=StratifiedKFold(n_splits=5),
#     stack_method="predict_proba",
#     n_jobs=-1,
# )

# %%
# from sklearn.tree import DecisionTreeClassifier

# %%
# rf_model = joblib.load("models/rf_model.pkl")
# hgb

# %%
# stack = StackingClassifier(
#     estimators=[
#         ("rf", rf_model),
#         ("hgb", hgb_model)
#     ],
#     final_estimator=DecisionTreeClassifier(random_state=42),
#     cv="prefit"
# )

# %%
# stack.fit(X_train_pcd, y_train)

# %%
# create_submission_file(
#     stack,
#     X_train_pcd,
#     y_train,
#     X_test_pcd,
#     save_name="stack_rf_hgb_dt",
# )

# %%
# evaluate_model_performance(stack, X_train_pcd, y_train)

# %%
# create_submission_file(stack, X_train_pcd, y_train, X_test_pcd, save_name="stacking_ensemble_fe_soiltype_breakdown")

# %% [markdown]
# # Feature selection

# %%
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedKFold
from sklearn.inspection import permutation_importance

# %%
# Multi-Model Feature Selection (prefit)
RANDOM_STATE = 42

models_fs = {
    # "lgbm": LGBMClassifier(n_estimators=500, random_state=RANDOM_STATE),
    "rf": RandomForestClassifier(n_estimators=500, random_state=RANDOM_STATE, n_jobs=-1),
    # "logreg": Pipeline([
    #     ("scaler", StandardScaler()),
    #     ("model", LogisticRegression(penalty='l1', solver='saga', C=0.5, max_iter=5000, random_state=RANDOM_STATE))
    # ])
}

feature_sets = []

for name, model in models_fs.items():
    print(f"Fitting model for feature selection: {name}")
    model.fit(X_train_pcd, y_train)

    # Extract importances
    if name in ["lgbm", "rf"]:
        imp = pd.Series(model.feature_importances_, index=X_train_pcd.columns)
    else:  # Logistic Regression L1
        imp = pd.Series(np.abs(model.named_steps["model"].coef_[0]), index=X_train_pcd.columns)

    # Keep features above median
    top_features = imp[imp > imp.median()].index.tolist()
    feature_sets.append(set(top_features))

# Intersection of top features across models for robustness
robust_features_multi = set.intersection(*feature_sets)
X_train_selected = X_train_pcd[list(robust_features_multi)].copy()
X_test_selected = X_test_pcd[list(robust_features_multi)].copy()
print("Features after multi-model agreement:", X_train_selected.shape[1])

# %%
robust_features_multi

# %%
# # Cross-Validated Feature Importance (LGBM)

# N_FOLDS = 5
# skf = StratifiedKFold(n_splits=N_FOLDS, shuffle=True, random_state=RANDOM_STATE)

# feature_importances_cv = pd.DataFrame(0, index=X_train_selected.columns, columns=range(N_FOLDS))

# for fold, (train_idx, val_idx) in enumerate(skf.split(X_train_selected, y_train)):
#     X_tr, X_val = X_train_selected.iloc[train_idx], X_train_selected.iloc[val_idx]
#     y_tr, y_val = y_train.iloc[train_idx], y_train.iloc[val_idx]

#     model = LGBMClassifier(n_estimators=500, random_state=RANDOM_STATE)
#     model.fit(X_tr, y_tr)

#     feature_importances_cv[fold] = model.feature_importances_

# # Keep features appearing in most folds
# fold_threshold = 0.6 * N_FOLDS
# stable_features = feature_importances_cv.apply(lambda x: x > 0).sum(axis=1)
# robust_features_cv = stable_features[stable_features >= fold_threshold].index.tolist()
# X_train_robust = X_train_selected[robust_features_cv].copy()
# X_test_robust = X_test_selected[robust_features_cv].copy()
# print("Features after CV stability check:", X_train_robust.shape[1])

# %%
# robust_features_cv

# %%
# Permutation Importance
final_model = LGBMClassifier(n_estimators=500, random_state=RANDOM_STATE)
final_model.fit(X_train_selected, y_train)

perm_importance = permutation_importance(
    final_model, X_train_selected, y_train, n_repeats=20, random_state=RANDOM_STATE
)
perm_importances = pd.Series(perm_importance.importances_mean, index=X_train_selected.columns)

# Keep only features with positive permutation importance
robust_features_final = perm_importances[perm_importances > 0].index.tolist()
X_train_final = X_train_selected[robust_features_final].copy()
X_test_final = X_test_selected[robust_features_final].copy()

print("Final feature count:", X_train_final.shape[1])
print("Final selected features:\n", robust_features_final)

# %%
sorted_importances = perm_importances[robust_features_final].sort_values(ascending=False)

plt.figure(figsize=(10,6))
sns.barplot(
    x=sorted_importances.values,
    y=sorted_importances.index,
    palette="viridis"
)

plt.title("Final Feature Importances (Permutation Importance)")
plt.xlabel("Importance Score")
plt.ylabel("Feature")
plt.tight_layout()
plt.savefig("output/plots/final_feature_importances.png")
plt.show()

# %%
# Base models
base_estimators = [
    (
        "cat",
        CatBoostClassifier(
            loss_function="MultiClass",
            verbose=0,
        ),
    ),
    (
        "lgbm",
        LGBMClassifier(
            n_estimators=500,
            max_depth=-1,
        ),
    ),
    (
        "xgb",
        XGBClassifier(
            n_estimators=500,
            learning_rate=0.05,
        ),
    ),
    (
        "hgb",
        HistGradientBoostingClassifier(
            max_iter=1000,
            random_state=1,
            # **study.best_params
        ),
    ),
    ("rf", RandomForestClassifier(max_depth=18, n_estimators=500)),
]

meta_model = LogisticRegression()

stack = StackingClassifier(
    estimators=base_estimators,
    final_estimator=meta_model,
    cv=StratifiedKFold(n_splits=5),
    stack_method="predict_proba",
    n_jobs=-1,
)

# %%
stack.fit(X_train_final, y_train)

# %%
evaluate_model_performance(stack, X_train_final, y_train)

# %%
create_submission_file(
    stack,
    X_train_pcd,
    y_train,
    X_test_pcd,
    save_name="stacking_ensemble_final_features",
)

# %% [markdown]
# # Evaluating final predictions

# %%
y_pred = get_val_predictions(stack, X_train_pcd, y_train)

# %%
X_temp = X_train_pcd.copy()
X_temp["predicted_cover_type"] = y_pred
X_temp["true_cover_type"] = y_train
X_temp["accuracy"] = X_temp["predicted_cover_type"] == X_temp["true_cover_type"]
X_temp["wilderness_area"] = X_temp["Wilderness_Area1"] * 1 + X_temp["Wilderness_Area2"] * 2 + X_temp["Wilderness_Area3"] * 3 + X_temp["Wilderness_Area4"] * 4
table = X_temp.groupby("wilderness_area").agg(
    {
        "accuracy": ["mean"],
    }
)

table.columns = ["mean_accuracy"]
print(table.to_latex())

# %%
cover_types = sorted(X_temp["true_cover_type"].unique())

fig, axes = plt.subplots(2, 2, figsize=(12, 10))
axes = axes.flatten()

for i, wtype in enumerate(range(1, 5)):
    subset = X_temp[X_temp["wilderness_area"] == wtype]

    # Compute normalized confusion matrix (proportion per predicted class)
    cm = confusion_matrix(
        subset["true_cover_type"],
        subset["predicted_cover_type"],
        labels=cover_types,
        normalize="pred"
    )

    # Mask zero entries
    mask = cm == 0

    sns.heatmap(
        cm,
        annot=True,
        fmt=".2f",
        cmap="Blues",
        cbar=i==3,  # show colorbar only on last subplot
        ax=axes[i],
        xticklabels=cover_types,
        yticklabels=cover_types,
        mask=mask
    )

    axes[i].set_title(f"Wilderness Area {wtype}", fontsize=14)
    axes[i].set_xlabel("Predicted Cover Type")
    axes[i].set_ylabel("True Cover Type")

plt.tight_layout()
plt.savefig("output/plots/confusion_matrices_by_wilderness_area.png")
plt.show()

# %% [markdown]
# ## LazyPredict

# %%
# from lazypredict.Supervised import LazyClassifier

# # Split data
# X_tr, X_t, y_tr, y_t = train_test_split(
#     X_train, y_train, test_size=0.2, stratify=y_train, random_state=42
# )

# # Run LazyPredict
# clf = LazyClassifier(ignore_warnings=False, custom_metric=None)
# models, predictions = clf.fit(X_tr, X_t, y_tr, y_t)

# print(models)
